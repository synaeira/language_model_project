# %%
from training import Trainer
import matplotlib.pyplot as plt
import testing


# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %% [markdown]
# ---

# %% [markdown]
# ## Shakespeare dataset

# %%
train = Trainer(datafile="../datasets/shakespeare-data.txt", 
                block_size=128, 
                batch_size=128,
                dim_emb=768, 
                hidden_layer=128, 
                num_head=8, 
                num_transformer=12, 
                learning_rate=0.0001, 
                iteration=6000)

train.run()
train.save_model(path="../trained_models/shakespeare-model.pth")

plt.figure(figsize=(10, 6))
plt.plot(train.running_loss)
plt.title("Training Loss")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.grid(True)
plt.show()
# Out:
# wandb: Using wandb-core as the SDK backend.  Please refer to https://wandb.me/wandb-core for more information.
# wandb: Currently logged in as: psykose4003 (psykose4003-universit-de-gen-ve). Use `wandb login --relogin` to force relogin
# Tracking run with wandb version 0.19.0
# Run data is saved locally in <code>/Users/stacy/Desktop/deep_learning/language_model_project/src/wandb/run-20241210_211802-qyf4ej2w</code>
# Syncing run <strong><a href='https://wandb.ai/psykose4003-universit-de-gen-ve/loss%20shakespeare/runs/qyf4ej2w' target="_blank">lyric-music-3</a></strong> to <a href='https://wandb.ai/psykose4003-universit-de-gen-ve/loss%20shakespeare' target="_blank">Weights & Biases</a> (<a href='https://wandb.me/developer-guide' target="_blank">docs</a>)<br/>
#  View project at <a href='https://wandb.ai/psykose4003-universit-de-gen-ve/loss%20shakespeare' target="_blank">https://wandb.ai/psykose4003-universit-de-gen-ve/loss%20shakespeare</a>
# ...

# %%
# train = Trainer(load_path="../trained_models/shakespeare-model.pth")

initial_phrase = "O God, O God!"
generated_text = testing.text_generation(train, initial_phrase, num_chars=1000, block_size=128)

print(generated_text)
# Out:
# O God, O God!
# Be it flaves, I come, you not choose me to my state:
# I will not buy your youth.
#
# ISABELLA:
# O, pardon me, my lord;
# Your first in your mind honour is the rest.
#
# GLOUCESTER:
# I would you proceed Harryion, with silence
# Either Even in the man's, with a respect flowers
# Of that slew them father, hence and the abuses of your
# person and the youth i' the city is right:
# Save him, enjoy'd or pale.
# O' ! love! for uscon, I can my breath!
# The enemies of you, early and such loves you.
#
# BIANCA:
# Let's grant them one, being the time army;
# For I am his come and know to effemind it.
#
# GRUMIO:
# He was not reason to be drawn out personaged; on the
# labour and the expost the chronicion, then
# to die  little will some other against here.
#
# ROMEO:
# And you, the beastless kind of Carth,
# Anding all the prevo't as sake fair,
# And to the hand that did the gatering of Camillo;
# Do not him entertainle so,
# Let be deserve not what we have been disquised:
# ...

# %% [markdown]
# ---

# %% [markdown]
# ## Jul Dataset

# %%
train_jul = Trainer(datafile="../datasets/jul-data-subset.txt", 
                block_size=128, 
                batch_size=128,
                dim_emb=768, 
                hidden_layer=128, 
                num_head=8, 
                num_transformer=12, 
                learning_rate=0.0001, 
                iteration=6000)

train_jul.run()
train_jul.save_model(path="../trained_models/jul-model.pth")

plt.figure(figsize=(10, 6))
plt.plot(train_jul.running_loss)
plt.title("Training Loss")
plt.xlabel("Iterations")
plt.ylabel("Loss")
plt.grid(True)
plt.show()
# Out:
# Training Progress: 6002batch [8:42:41,  5.23s/batch]
#     <style>
#         .wandb-row {
#             display: flex;
#             flex-direction: row;
#             flex-wrap: wrap;
#             justify-content: flex-start;
#             width: 100%;
#         }
#         .wandb-col {
#             display: flex;
#             flex-direction: column;
#             flex-basis: 100%;
#             flex: 1;
#             padding: 10px;
#         }
#     </style>
# <div class="wandb-row"><div class="wandb-col"><h3>Run history:</h3><br/><table class="wandb"><tr><td>loss jul</td><td>█▆▆▅▅▄▄▄▄▄▄▄▄▃▃▄▃▃▃▂▂▂▂▂▂▂▂▂▂▁▁▁▁▁▁▁▁▁▁▁</td></tr><tr><td>loss shakespeare</td><td>█▅▄▂▂▁▁</td></tr></table><br/></div><div class="wandb-col"><h3>Run summary:</h3><br/><table class="wandb"><tr><td>loss jul</td><td>0.256</td></tr><tr><td>loss shakespeare</td><td>3.3255</td></tr></table><br/></div></div>
# ...

# %%
# train_jul = Trainer(datafile="../datasets/jul-data-subset.txt", load_path="../trained_models/jul-model.pth")


initial_phrase = "Wesh Alors "
generated_text = testing.text_generation(train_jul, initial_phrase, num_chars=1000, block_size=128)

print(generated_text)
# Out:
# Wesh Alors la zone
# Aquarium dans la zon’
# J’ai encore faim de mes où j’suis
# J’tris en D’ou'or en V-Porsco, t’as l’enfort
# Si l’état veut la guerre, faire un tour valide
# Comme Un Pontant que de range, danse-le, tu connais
# Ils ont tous faire le dirignant, Jul il fait des gens il faut pas v'se vouler des gros niques tout
# Ouais tous la montre au quand j'te chante, ouais, halla
# J'dégaäine, oh, hey, hey hey
# Marseille c'est pas Homme, la Kalash’ j’suis dans un dos
# Tu peux t'prendre un tasse au Pana Lise amis
# T’as beau charbon, tu t’embardis pour toute  c’qui m’font rire
# Tout j’peux rendre au pire
# J’peux te dire que c’est un milliar, mais j’reste te même sur en train d’jour faire le sourd
# Tour la vie va danser faire un course
# J’sais qu’tu fais l’gros, mais on t’voit plus (plus, pourquoi)
# J’ai p’t-être dit faut faire gaffe sur les gênars, j’raconte du Runnetrovs
# J’ai peur d’plus envie d’te mettre
# J’ai pensé dans le vez quand j’m’en tape du biff du lourdeur
# ...
